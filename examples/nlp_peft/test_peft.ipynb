# %%
# %load_ext autoreload
# %autoreload 2

# %%
import renate_peft_config

# %%
model = renate_peft_config.model_fn()

# %%
for x in model.named_parameters():
    if x[1].requires_grad:
        print(x[0])
# Out:
# _model.base_model.model.transformer.h.0.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.0.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.1.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.1.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.2.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.2.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.3.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.3.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.4.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.4.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.5.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.5.attn.c_attn.lora_B.weight
# _model.base_model.model.transformer.h.6.attn.c_attn.lora_A.weight
# _model.base_model.model.transformer.h.6.attn.c_attn.lora_B.weight
# ...
